# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# ### Temperature

# %%
temperature = pd.read_csv('global_temperatures.csv')
temperature
# Out:
#      Year  TemperatureDeviation
# 0    1880                 -0.20
# 1    1881                 -0.12
# 2    1882                 -0.10
# 3    1883                 -0.21
# 4    1884                 -0.28
# ..    ...                   ...
# 132  2012                  0.63
# 133  2013                  0.65
# 134  2014                  0.74
# 135  2015                  0.87
# 136  2016                  0.99
#
# [137 rows x 2 columns]

# %%
plt.plot(temperature['Year'], temperature['TemperatureDeviation'], color='red')
plt.xlabel("Year")
plt.ylabel("TemperatureDeviation")
# Out:
# Text(0, 0.5, 'TemperatureDeviation')

# %%
temperature.isnull().sum()
# Out:
# Year                    0
# TemperatureDeviation    0
# dtype: int64

# %% [markdown]
# ### Agri-food CO2 Emission Data

# %%
agrifood = pd.read_csv('agrifood.csv')
agrifood.head()
# Out:
#    Year  Savanna fires  Forest fires  Rice Cultivation  \
# 0  1990    265533.1965   203871.7269     929823.919130
# 1  1991    265533.1965   203871.7269     930480.142397
# 2  1992    265533.1965   203871.7267     939513.173286
# 3  1993    265533.1964   203871.7267     924193.393558
# 4  1994    265533.1964   203871.7267     927782.202763
#
#    Drained organic soils (CO2)  Pesticides Manufacturing  Food Transport  \
# 0                  752445.9744              55011.031460   317837.864552
# 1                  752445.9744              54433.936841   326979.000938
# 2                  752445.9743              57481.699902   329402.513986
# 3                  752878.5072              57749.542893   331280.768609
# 4                  752547.1299              62186.034696   330295.753344
#
#    Food Household Consumption    Food Retail  On-farm Electricity Use  \
# 0                 543237.6491  273178.600825            219106.922025
# ...

# %%
agrifood
# Out:
#     Year  Savanna fires  Forest fires  Rice Cultivation  \
# 0   1990    265533.1965   203871.7269     929823.919130
# 1   1991    265533.1965   203871.7269     930480.142397
# 2   1992    265533.1965   203871.7267     939513.173286
# 3   1993    265533.1964   203871.7267     924193.393558
# 4   1994    265533.1964   203871.7267     927782.202763
# 5   1995    265533.1964   203871.7267     933802.063726
# 6   1996    244594.5738   183710.0540     941701.857148
# 7   1997    235599.9088   257645.3790     950298.125679
# 8   1998    279330.1943   316956.1569     940894.534092
# 9   1999    285014.4256   249655.2145     969954.310418
# 10  2000    298790.7344   165653.4328     949645.603769
# 11  2001    303729.8995   120587.0646     934638.900047
# 12  2002    325070.8902   153113.6460     923770.647197
# 13  2003    265316.7984   209989.2373     915413.043207
# 14  2004    295376.5441   219782.7603     938384.682204
# 15  2005    271094.6469   210569.4800     957640.907581
# ...

# %%
agrifood.describe()
# Out:
#               Year  Savanna fires   Forest fires  Rice Cultivation  \
# count    27.000000      27.000000      27.000000         27.000000
# mean   2003.000000  271215.952489  204399.696552     952744.016979
# std       7.937254   31057.981047   36016.705407      22106.498853
# min    1990.000000  219738.378500  120587.064600     915413.043207
# 25%    1996.500000  249855.081950  187464.213950     934220.481887
# 50%    2003.000000  265533.196500  203871.726700     949645.603769
# 75%    2009.500000  290195.484850  210279.358650     973976.846539
# max    2016.000000  339758.677900  316956.156900     986583.602376
#
#        Drained organic soils (CO2)  Pesticides Manufacturing  Food Transport  \
# count                    27.000000                 27.000000       27.000000
# mean                 781179.601437              74216.381590   419442.259923
# std                   24421.958372              10742.859643    77697.915069
# ...

# %%
agrifood_scaled = pd.read_csv('agrifood_scaled.csv')
agrifood_scaled
# Out:
#     Year  Savanna fires  Forest fires  Rice Cultivation  \
# 0   1990      -0.186458     -0.014938         -1.056554
# 1   1991      -0.186458     -0.014938         -1.026304
# 2   1992      -0.186458     -0.014938         -0.609906
# 3   1993      -0.186458     -0.014938         -1.316106
# 4   1994      -0.186458     -0.014938         -1.150672
# 5   1995      -0.186458     -0.014938         -0.873172
# 6   1996      -0.873479     -0.585389         -0.509013
# 7   1997      -1.168605      1.506522         -0.112749
# 8   1998       0.266238      3.184650         -0.546229
# 9   1999       0.452744      1.280450          0.793348
# 10  2000       0.904761     -1.096279         -0.142828
# 11  2001       1.066821     -2.371378         -0.834597
# 12  2002       1.767045     -1.451077         -1.335593
# 13  2003      -0.193558      0.158149         -1.720856
# 14  2004       0.792738      0.435245         -0.661926
# 15  2005      -0.003980      0.174567          0.225733
# ...

# %% [markdown]
# ### Correlation Analysis

# %%
round(agrifood_scaled.corr(), 3)
# Out:
#                                   Year  Savanna fires  Forest fires  \
# Year                             1.000         -0.075        -0.135
# Savanna fires                   -0.075          1.000        -0.172
# Forest fires                    -0.135         -0.172         1.000
# Rice Cultivation                 0.812         -0.192         0.037
# Drained organic soils (CO2)      0.982         -0.093        -0.147
# Pesticides Manufacturing         0.940          0.090        -0.100
# Food Transport                   0.987         -0.136        -0.130
# Food Household Consumption       0.990         -0.140        -0.133
# Food Retail                      0.938         -0.207        -0.131
# On-farm Electricity Use          0.915         -0.160        -0.050
# Food Packaging                   0.959         -0.126        -0.075
# Agrifood Systems Waste Disposal  0.976          0.033        -0.131
# Food Processing                  0.921         -0.048        -0.078
# ...

# %%
plt.figure(figsize=(14,8))
sns.set_theme(style="white")
corr = agrifood_scaled.corr()
heatmap = sns.heatmap(corr, annot=True, cmap="Blues", fmt='.1g')

# %%
columns = ['Savanna fires', 'Forest fires', 'Rice Cultivation',
           'Drained organic soils (CO2)', 'Pesticides Manufacturing',
           'Food Transport', 'Food Household Consumption', 'Food Retail',
           'On-farm Electricity Use', 'Food Packaging',
           'Agrifood Systems Waste Disposal', 'Food Processing',
           'Fertilizers Manufacturing', 'IPPU', 'Manure left on Pasture',
           'Fires in organic soils', 'Fires in humid tropical forests',
           'TemperatureDeviation']
sns.pairplot(agrifood[columns])

# %%
corr_bar = corr.iloc[:, -1]
corr_bar = pd.DataFrame(corr_bar)
corr_bar = corr_bar.drop(['Year', 'TemperatureDeviation'], axis=0)
corr_bar = corr_bar.rename({'TemperatureDeviation':'Correlation'}, axis=1)
corr_bar = corr_bar.sort_values(['Correlation'], ascending=True, key=abs)
corr_bar
# Out:
#                                  Correlation
# Forest fires                        0.040565
# Fires in organic soils              0.088342
# Savanna fires                      -0.152014
# Fires in humid tropical forests     0.220264
# Rice Cultivation                    0.593607
# On-farm Electricity Use             0.687677
# Food Processing                     0.732629
# Food Packaging                      0.779861
# Pesticides Manufacturing            0.783212
# Agrifood Systems Waste Disposal     0.799514
# Food Retail                         0.804923
# Drained organic soils (CO2)         0.816666
# IPPU                                0.822975
# Food Household Consumption          0.833762
# Manure left on Pasture              0.836981
# Food Transport                      0.844339
# Fertilizers Manufacturing           0.862064

# %%
plt.figure(figsize=(14, 10), dpi=80)
plt.hlines(y=corr_bar.index, xmin=0, xmax=corr_bar.Correlation, alpha=0.4, linewidth=15)
plt.gca().set(ylabel='Variables', xlabel='Correlation')
plt.yticks(corr_bar.index)
plt.title('Correlation')
plt.grid(linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# __5 highest correlations__
# - Fertilizers Manufacturing
# - Food Transport
# - Manure left on Pasture
# - Food Household Consumption
# - IPPU

# %% [markdown]
# __correlation test__

# %%
from scipy.stats.stats import pearsonr

print("Savanna fires: ", pearsonr(agrifood_scaled.iloc[:, 1], agrifood_scaled.iloc[:, -1]))
print("Forest fires: ", pearsonr(agrifood_scaled.iloc[:, 2], agrifood_scaled.iloc[:, -1]))
print("Rice Cultivation: ", pearsonr(agrifood_scaled.iloc[:, 3], agrifood_scaled.iloc[:, -1]))
print("Drained organic soils (CO2): ", pearsonr(agrifood_scaled.iloc[:, 4], agrifood_scaled.iloc[:, -1]))
print("Pesticides Manufacturing: ", pearsonr(agrifood_scaled.iloc[:, 5], agrifood_scaled.iloc[:, -1]))
print("Food Transport: ", pearsonr(agrifood_scaled.iloc[:, 6], agrifood_scaled.iloc[:, -1]))
print("Food Household Consumption: ", pearsonr(agrifood_scaled.iloc[:, 7], agrifood_scaled.iloc[:, -1]))
print("Food Retail: ", pearsonr(agrifood_scaled.iloc[:, 8], agrifood_scaled.iloc[:, -1]))
print("On-farm Electricity Use: ", pearsonr(agrifood_scaled.iloc[:, 9], agrifood_scaled.iloc[:, -1]))
print("Food Packaging: ", pearsonr(agrifood_scaled.iloc[:, 10], agrifood_scaled.iloc[:, -1]))
print("Agrifood Systems Waste Disposal: ", pearsonr(agrifood_scaled.iloc[:, 11], agrifood_scaled.iloc[:, -1]))
print("Food Processing: ", pearsonr(agrifood_scaled.iloc[:, 12], agrifood_scaled.iloc[:, -1]))
print("Fertilizers Manufacturing: ", pearsonr(agrifood_scaled.iloc[:, 13], agrifood_scaled.iloc[:, -1]))
print("IPPU: ", pearsonr(agrifood_scaled.iloc[:, 14], agrifood_scaled.iloc[:, -1]))
print("Manure left on Pasture: ", pearsonr(agrifood_scaled.iloc[:, 15], agrifood_scaled.iloc[:, -1]))
print("Fires in organic soils: ", pearsonr(agrifood_scaled.iloc[:, 16], agrifood_scaled.iloc[:, -1]))
print("Fires in humid tropical forests: ", pearsonr(agrifood_scaled.iloc[:, 17], agrifood_scaled.iloc[:, -1]))
# Out:
# Savanna fires:  PearsonRResult(statistic=-0.15201421662261877, pvalue=0.449093074825881)
# Forest fires:  PearsonRResult(statistic=0.040565476733653724, pvalue=0.8407824620250556)
# Rice Cultivation:  PearsonRResult(statistic=0.5936072501612599, pvalue=0.0010985025103073555)
# Drained organic soils (CO2):  PearsonRResult(statistic=0.8166660936564833, pvalue=2.0433444854116977e-07)
# Pesticides Manufacturing:  PearsonRResult(statistic=0.783211836603814, pvalue=1.3664342198067594e-06)
# Food Transport:  PearsonRResult(statistic=0.8443385278279493, pvalue=3.098239174005368e-08)
# Food Household Consumption:  PearsonRResult(statistic=0.8337621132388715, pvalue=6.632713968640977e-08)
# Food Retail:  PearsonRResult(statistic=0.8049232208689883, pvalue=4.147715615316383e-07)
# On-farm Electricity Use:  PearsonRResult(statistic=0.6876769952324304, pvalue=7.386479122954442e-05)
# Food Packaging:  PearsonRResult(statistic=0.7798605087210019, pvalue=1.622984208453121e-06)
# ...

# %% [markdown]
# __4 lowest correlations__
# - Savanna fires: pvalue=0.449093074825881 / cor: -0.152014
# - Forest fires: pvalue=0.8407824620250556 / cor: 0.040565
# - Fires in organic soils: pvalue=0.6612577609485565 / cor: 0.088342
# - Fires in humid tropical forests: pvalue=0.26959463421136265 / cor: 0.220264

# %% [markdown]
# __scatter plots of 5 highest correlations with TemperatureDeviation__

# %%
# Fertilizers Manufacturing
plt.scatter(agrifood['TemperatureDeviation'], agrifood['Fertilizers Manufacturing'])

# %%
# Food Transport
plt.scatter(agrifood['TemperatureDeviation'], agrifood['Food Transport'])

# %%
# Manure left on Pasture
plt.scatter(agrifood['TemperatureDeviation'], agrifood['Manure left on Pasture'])

# %%
# Food Household Comsumption
plt.scatter(agrifood['TemperatureDeviation'], agrifood['Food Household Consumption'])

# %%
# IPPU
plt.scatter(agrifood['TemperatureDeviation'], agrifood['IPPU'])

# %% [markdown]
# __scatter plots of 4 lowest correlations with TemperatureDeviation__

# %%
# Savanna fires
plt.scatter(agrifood['TemperatureDeviation'], agrifood['Savanna fires'])

# %%
# Forest fires
plt.scatter(agrifood['TemperatureDeviation'], agrifood['Forest fires'])

# %%
# Fires in organic soils
plt.scatter(agrifood['TemperatureDeviation'], agrifood['Fires in organic soils'])

# %%
# Fires in humid tropical forests
plt.scatter(agrifood['TemperatureDeviation'], agrifood['Fires in humid tropical forests'])

# %% [markdown]
# ### Time Series Analysis, VAR model

# %% [markdown]
# with two variables, Agrifood Systems Waste Disposal and IPPU

# %%
import statsmodels.api as sm
from statsmodels.tsa.api import VAR
from statsmodels.tsa.stattools import adfuller

# %%
df = agrifood[['Agrifood Systems Waste Disposal', 'IPPU', 'TemperatureDeviation']]
df.index = agrifood["Year"]
df.head()
# Out:
#       Agrifood Systems Waste Disposal          IPPU  TemperatureDeviation
# Year
# 1990                     1.127063e+06  1.922974e+06                  0.44
# 1991                     1.151532e+06  1.959441e+06                  0.43
# 1992                     1.172248e+06  2.004423e+06                  0.23
# 1993                     1.193446e+06  2.074678e+06                  0.24
# 1994                     1.212281e+06  2.186140e+06                  0.32

# %%
df.describe()
# Out:
#        Agrifood Systems Waste Disposal          IPPU  TemperatureDeviation
# count                     2.700000e+01  2.700000e+01              27.00000
# mean                      1.335984e+06  3.647691e+06               0.56037
# std                       1.030303e+05  1.407537e+06               0.17586
# min                       1.127063e+06  1.922974e+06               0.23000
# 25%                       1.258904e+06  2.440183e+06               0.43500
# 50%                       1.351978e+06  3.255129e+06               0.60000
# 75%                       1.426022e+06  4.699755e+06               0.64500
# max                       1.459606e+06  5.998999e+06               0.99000

# %%
df.plot(figsize = (8,5))
# Out:
# <Axes: xlabel='Year'>

# %%
df['TemperatureDeviation'].plot()
# Out:
# <Axes: xlabel='Year'>

# %%
# stationarity
adf_ASWD = adfuller(df['Agrifood Systems Waste Disposal'])
adf_IPPU = adfuller(df['IPPU'])
adf_TD = adfuller(df['TemperatureDeviation'])
print("p-value for Agrifood Systems Waste Disposal: {}".format(adf_ASWD[1]))
print("p-value for IPPU: {}".format(adf_IPPU[1]))
print("p-value for TemperatureDeviation: {}".format(adf_TD[1]))
# Out:
# p-value for Agrifood Systems Waste Disposal: 0.00419553630045962
# p-value for IPPU: 0.9936132536929111
# p-value for TemperatureDeviation: 0.8531533506108475

# %%
# differencing the data (x(t)-x(t-1)) until we get a point where the series is stationary
df_stationary = df.diff().dropna()

# %%
df_stationary.plot()
# Out:
# <Axes: xlabel='Year'>

# %%
plt.plot(df_stationary['TemperatureDeviation'])

# %%
# after differentiation
adf_ASWD_diff = adfuller(df_stationary['Agrifood Systems Waste Disposal'])
adf_IPPU_diff = adfuller(df_stationary['IPPU'])
adf_TD_diff = adfuller(df_stationary['TemperatureDeviation'])
print("p-value for Agrifood Systems Waste Disposal: {}".format(adf_ASWD_diff[1]))
print("p-value for IPPU: {}".format(adf_IPPU_diff[1]))
print("p-value for TemperatureDeviation: {}".format(adf_TD_diff[1]))
# Out:
# p-value for Agrifood Systems Waste Disposal: 0.000572844647297303
# p-value for IPPU: 0.5017051639984066
# p-value for TemperatureDeviation: 2.4215502370478316e-06

# %%
train = df_stationary.iloc[:18]
test = df_stationary.iloc[18:]

# %%
train.shape
# Out:
# (18, 3)

# %%
test.shape
# Out:
# (8, 3)

# %%
forecasting_model = VAR(train)
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
# optimal lag order
forecasting_model = VAR(train)
x = forecasting_model.select_order(maxlags=3)
x.summary()
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# <class 'statsmodels.iolib.table.SimpleTable'>

# %%
results = forecasting_model.fit(3)
results.summary()
# Out:
#   Summary of Regression Results
# ...
# Model:                         VAR
# Method:                        OLS
# Date:           Sun, 05, May, 2024
# Time:                     20:58:23
# --------------------------------------------------------------------
# No. of Equations:         3.00000    BIC:                    38.5063
# Nobs:                     15.0000    HQIC:                   37.0752
# Log likelihood:          -312.029    FPE:                2.93641e+16
# AIC:                      37.0902    Det(Omega_mle):     6.34264e+15
# --------------------------------------------------------------------
# Results for equation Agrifood Systems Waste Disposal
# ...
#                                         coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------------------------
# const                                 -29825.847177     23048.288271           -1.294           0.196
# ...

# %%
laaged_values = train.values[-3:]
forecast = pd.DataFrame(results.forecast(y= laaged_values, steps=8), index = test.index, columns= ['Agrifood Systems Waste Disposal_d', 'IPPU_d', 'TemperatureDeviation_d'])
forecast
# Out:
#       Agrifood Systems Waste Disposal_d         IPPU_d  TemperatureDeviation_d
# Year
# 2009                      -21960.730942  131259.256001                0.061606
# 2010                       14060.528876  177390.517294                0.192538
# 2011                       -4865.931037  430909.503123               -0.087450
# 2012                       19486.612692  419897.029703                0.036514
# 2013                       18193.655531  316675.159665               -0.048618
# 2014                        -186.103440  197020.989546               -0.012523
# 2015                        5733.671367  102816.613066                0.063752
# 2016                       -6480.445952  187302.731650               -0.006522

# %%
forecast["Agrifood Systems Waste Disposal_f"] = df["Agrifood Systems Waste Disposal"].iloc[-8-1] + forecast['Agrifood Systems Waste Disposal_d'].cumsum()
forecast["IPPU_f"] = df["IPPU"].iloc[-8-1] + forecast['IPPU_d'].cumsum()
forecast["TemperatureDeviation_f"] = df["TemperatureDeviation"].iloc[-8-1] + forecast['TemperatureDeviation_d'].cumsum()
forecast
# Out:
#       Agrifood Systems Waste Disposal_d         IPPU_d  \
# Year
# 2009                      -21960.730942  131259.256001
# 2010                       14060.528876  177390.517294
# 2011                       -4865.931037  430909.503123
# 2012                       19486.612692  419897.029703
# 2013                       18193.655531  316675.159665
# 2014                        -186.103440  197020.989546
# 2015                        5733.671367  102816.613066
# 2016                       -6480.445952  187302.731650
#
#       TemperatureDeviation_d  Agrifood Systems Waste Disposal_f        IPPU_f  \
# Year
# 2009                0.061606                       1.391700e+06  4.591294e+06
# 2010                0.192538                       1.405760e+06  4.768685e+06
# 2011               -0.087450                       1.400895e+06  5.199594e+06
# 2012                0.036514                       1.420381e+06  5.619491e+06
# ...

# %%
test = df.iloc[-8:,:]
test["Agrifood Systems Waste Disposal_f"] = forecast["Agrifood Systems Waste Disposal_f"]
test["IPPU_f"] = forecast["IPPU_f"]
test["TemperatureDeviation_f"] = forecast["TemperatureDeviation_f"]
test.plot()
# Out:
# <Axes: xlabel='Year'>

# %%
test = df.iloc[-8:,:1]
test["Agrifood Systems Waste Disposal_f"] = forecast["Agrifood Systems Waste Disposal_f"]
test.plot()
# Out:
# <Axes: xlabel='Year'>

# %%
test = df.iloc[:, :1]
test["Agrifood Systems Waste Disposal_f"] = forecast["Agrifood Systems Waste Disposal_f"]
test.plot()
plt.ylabel("CO2 Emission")
plt.legend(['Agrifood Systems Waste Disposal', 'forecasted'])

# %%
test = df.iloc[-8:,1:2]
test["IPPU_f"] = forecast["IPPU_f"]
test.plot()
plt.ylabel("CO2 Emission")
# Out:
# Text(0, 0.5, 'CO2 Emission')

# %%
test = df.iloc[:, 1:2]
test["IPPU_f"] = forecast["IPPU_f"]
test.plot()
plt.ylabel("CO2 Emission")
plt.legend(['IPPU', 'forecasted'])

# %%
test = df.iloc[-8:,2:3]
test["TemperatureDeviation_f"] = forecast["TemperatureDeviation_f"]
test.plot()
# Out:
# <Axes: xlabel='Year'>

# %%
test = df.iloc[:, 2:3]
test["TemperatureDeviation_f"] = forecast["TemperatureDeviation_f"]
test.plot()
plt.ylabel("CO2 Emission")
plt.legend(['TemperatureDeviation', 'forecasted'])

# %% [markdown]
# __Forecasting for the future__

# %%
train = df_stationary

# %%
train.shape
# Out:
# (26, 3)

# %%
forecasting_model = VAR(train)
# Out:
# C:\Users\USER\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)

# %%
results = forecasting_model.fit(3)
results.summary()
# Out:
#   Summary of Regression Results
# ...
# Model:                         VAR
# Method:                        OLS
# Date:           Sun, 05, May, 2024
# Time:                     20:59:41
# --------------------------------------------------------------------
# No. of Equations:         3.00000    BIC:                    39.3933
# Nobs:                     23.0000    HQIC:                   38.2847
# Log likelihood:          -503.897    FPE:                3.51417e+16
# AIC:                      37.9122    Det(Omega_mle):     1.18977e+16
# --------------------------------------------------------------------
# Results for equation Agrifood Systems Waste Disposal
# ...
#                                         coefficient       std. error           t-stat            prob
# -----------------------------------------------------------------------------------------------------
# const                                   7688.667947     13143.970436            0.585           0.559
# ...

# %%
laaged_values = train.values[-3:]
forecast2 = pd.DataFrame(results.forecast(y= laaged_values, steps=10), columns= ['Agrifood Systems Waste Disposal_d', 'IPPU_d', 'TemperatureDeviation_d'])
forecast2
# Out:
#    Agrifood Systems Waste Disposal_d         IPPU_d  TemperatureDeviation_d
# 0                       18354.537924  546277.540702               -0.151814
# 1                       17908.833090  400976.902544               -0.095875
# 2                        4900.911359   14350.071990                0.121057
# 3                       -4298.107448   30062.273739                0.156626
# 4                        9621.219288  305685.367122               -0.002917
# 5                       18031.498139  392597.622440               -0.103608
# 6                       11551.991965  227045.226483                0.003439
# 7                        3245.114515   96383.207982                0.108838
# 8                        3866.546438  166772.268204                0.068417
# 9                       11523.195882  286826.547212               -0.023208

# %%
forecast2["Agrifood Systems Waste Disposal_f"] = df["Agrifood Systems Waste Disposal"].iloc[-1] + forecast2['Agrifood Systems Waste Disposal_d'].cumsum()
forecast2["IPPU_f"] = df["IPPU"].iloc[-1] + forecast2['IPPU_d'].cumsum()
forecast2["TemperatureDeviation_f"] = df["TemperatureDeviation"].iloc[-1] + forecast2['TemperatureDeviation_d'].cumsum()
forecast2
# Out:
#    Agrifood Systems Waste Disposal_d         IPPU_d  TemperatureDeviation_d  \
# 0                       18354.537924  546277.540702               -0.151814
# 1                       17908.833090  400976.902544               -0.095875
# 2                        4900.911359   14350.071990                0.121057
# 3                       -4298.107448   30062.273739                0.156626
# 4                        9621.219288  305685.367122               -0.002917
# 5                       18031.498139  392597.622440               -0.103608
# 6                       11551.991965  227045.226483                0.003439
# 7                        3245.114515   96383.207982                0.108838
# 8                        3866.546438  166772.268204                0.068417
# 9                       11523.195882  286826.547212               -0.023208
#
#    Agrifood Systems Waste Disposal_f        IPPU_f  TemperatureDeviation_f
# ...

# %%
temp = df.iloc[:, 2:3]
pred = pd.DataFrame(forecast2['TemperatureDeviation_f'])
pred = pred.set_index([pd.Index([2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024, 2025, 2026])])
pred.rename(columns={"TemperatureDeviation_f": "TemperatureDeviation"}, inplace=True)
pred = pd.concat([temp, pred])
pred
# Out:
#       TemperatureDeviation
# 1990              0.440000
# 1991              0.430000
# 1992              0.230000
# 1993              0.240000
# 1994              0.320000
# 1995              0.460000
# 1996              0.350000
# 1997              0.480000
# 1998              0.640000
# 1999              0.420000
# 2000              0.420000
# 2001              0.550000
# 2002              0.630000
# 2003              0.620000
# 2004              0.550000
# 2005              0.690000
# 2006              0.630000
# 2007              0.660000
# 2008              0.540000
# 2009              0.640000
# 2010              0.710000
# 2011              0.600000
# 2012              0.630000
# 2013              0.650000
# 2014              0.740000
# 2015              0.870000
# 2016              0.990000
# 2017              0.838186
# 2018              0.742311
# 2019              0.863369
# 2020              1.019995
# 2021              1.017079
# 2022              0.913471
# ...

# %%
pred.plot()
plt.xlabel("Year")
plt.ylabel("TemperatureDeviation")
plt.legend('', frameon=False)
